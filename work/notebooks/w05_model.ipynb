# %% [markdown]
# <a href="https://colab.research.google.com/github/rizwanmahnoor1905-web/Machine-learning-track/blob/main/work/notebooks/w05_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-08 — Capstone Modeling Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/rizwanmahnoor1905-web/Machine-learning-track/blob/main/work/notebooks/w05_model.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Method choice and why
#
# *Which method from the toolkit, and why it fits your lane.*

# %% [markdown]
# I chose a Decision Tree because my FlyRank task can be framed as a multiclass classification problem, with four possible recommended actions: connect GSC and GA4, connect GA4, connect GSC, or take no action. A Decision Tree is appropriate because it can learn simple decision rules from client-level features and is easy to interpret. It also provides a reasonable first ML model for comparison with my Week-4 rule-based baseline. I will evaluate the Decision Tree and the baseline on the same data and using the same metric to determine whether the added model complexity provides a meaningful improvement.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Split design
#
# *Grouped by client? Time-aware? Say why this split is honest for your question.*

# %% [markdown]
# I will use an 80/20 stratified train-test split. Each client_hash_id appears only once in the dataset, so grouped-by-client validation is not necessary and there is no risk of the same client's observations appearing in both sets. I will stratify by the target class so that the four action classes are represented proportionally in both the training and test sets. The test set will remain unseen during training and will be used to compare the Decision Tree against the Week-4 baseline on the same data and metric.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Train + compare vs my baseline
#
# *Same data, same metric, same split as your Week-4 baseline. Show the table.*

# %% [markdown]
# I will train a Decision Tree classifier using the training portion of the FlyRank data and evaluate it on the held-out test set. I will also apply my Week-4 rule-based baseline to the same test records. Both approaches will be evaluated using the same classification metric so that the comparison is fair. The results will be presented in a model-vs-baseline table to determine whether the Decision Tree provides a meaningful improvement over the simpler rule-based approach.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Errors and interpretation
#
# *Where is the model wrong? What does it lean on? A short error analysis beats a big metric table.*

# %% [markdown]
# I will analyze the cases where the Decision Tree prediction differs from the actual target. I will examine the most common misclassified classes and use a confusion matrix and error counts to identify patterns in the model's mistakes. In particular, I will check whether errors are concentrated in one of the recommended-action classes or whether some classes are frequently confused with each other. I will also examine the available features to understand why these cases may be difficult to classify. This analysis will help determine whether the model has learned useful patterns or whether its errors indicate that the available features are insufficient for improving on the Week-4 rule-based baseline.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Compare actual and predicted classes
errors = test_results[
    test_results["actual"] != test_results["predicted"]
]

print("Number of errors:", len(errors))
print("Error rate:", len(errors) / len(test_results))

# Most common types of errors
error_counts = (
    errors.groupby(["actual", "predicted"])
    .size()
    .reset_index(name="count")
    .sort_values("count", ascending=False)
)

error_counts

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
